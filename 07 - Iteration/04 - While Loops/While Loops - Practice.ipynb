# %%
value = 10
while value < 15:
    print(value)
    value = value + 1
# Out:
# 10
# 11
# 12
# 13
# 14

# %%
value = 10 
while value < 15:
    print(value)
    value = value - 1

# %%
price = 100
while price > 90:
    print(f'price = {price} - waiting to come down')
    # price = price -1 
    price -= 1
    print(f'buying at {price}')
# Out:
# price = 100 - waiting to come down
# buying at 99
# price = 99 - waiting to come down
# buying at 98
# price = 98 - waiting to come down
# buying at 97
# price = 97 - waiting to come down
# buying at 96
# price = 96 - waiting to come down
# buying at 95
# price = 95 - waiting to come down
# buying at 94
# price = 94 - waiting to come down
# buying at 93
# price = 93 - waiting to come down
# buying at 92
# price = 92 - waiting to come down
# buying at 91
# price = 91 - waiting to come down
# buying at 90

# %%
price = 100
while price < 50:
    print(f'price{price}')
print('done')
# Out:
# done

# %%
price = 100
while price > 90:
    print(price)
    price += 10

# %%
data = [100, 200, 300, 400, 500]
while len(data) > 0:
    last_element = data.pop()
    print(f'processing elements : {last_element}')
# Out:
# processing elements : 500
# processing elements : 400
# processing elements : 300
# processing elements : 200
# processing elements : 100

# %%
data = [100, 200, 300, 400, 500]

for i in range (len(data)):
    print(f'i = {i}')
    print(f'before removeing element: data = {data}')
    element = data.pop(0)    
    print(f'processing element: {element}')
    print(f'after remvoing element: data = {data}')
    print('='*12)
# Out:
# i = 0
# before removeing element: data = [100, 200, 300, 400, 500]
# processing element: 100
# after remvoing element: data = [200, 300, 400, 500]
# ...
# i = 1
# before removeing element: data = [200, 300, 400, 500]
# processing element: 200
# after remvoing element: data = [300, 400, 500]
# ...
# i = 2
# before removeing element: data = [300, 400, 500]
# processing element: 300
# after remvoing element: data = [400, 500]
# ...
# i = 3
# before removeing element: data = [400, 500]
# processing element: 400
# after remvoing element: data = [500]
# ...
# i = 4
# before removeing element: data = [500]
# processing element: 500
# after remvoing element: data = []
# ...
