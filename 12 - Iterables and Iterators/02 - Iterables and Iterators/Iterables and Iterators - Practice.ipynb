# %%
l = [1,2,3]
iterator = iter(l)
type(iterator)
next(iterator)
next(iterator)
next(iterator)
next(iterator)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[7], line 7
#       5 next(iterator)
#       6 next(iterator)
# ----> 7 next(iterator)
#
# StopIteration:

# %%
l = [1,2,3]
iterator = iter(l)
id(iterator)
# Out:
# 138241737482176

# %%
l = [1,2,3]
iterator = iter(l)
id(iterator)
next(iterator)
# Out:
# 1

# %%
l = [1,2,3,4,5]
for element in l:
    print(element)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
iterator = iter(l)
try:
    while True:
        element = next(iterator)
        print(element)
except StopIteration:
    print('done iterating')
    pass
# Out:
# 1
# 2
# 3
# 4
# 5
# done iterating

# %%
r = range(10)
r
r_iter = iter(r)
next(r_iter)
next(r_iter)
next(r_iter)
list(r_iter)
# Out:
# [3, 4, 5, 6, 7, 8, 9]

# %%
for i in range (100_000_000):
    print(i)
    if i > 4:
        break
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
from time import perf_counter
start = perf_counter()
l = range(100_000_000)
end = perf_counter()
print(f'elapsed: {end-start}')
# Out:
# elapsed: 2.5653999728092458e-05

# %%
from time import perf_counter
start = perf_counter()
l = list(range(100_000_000))
end = perf_counter()
print(f'elapsed: {end-start}')
# Out:
# elapsed: 3.6177781480000704

# %%
del l
