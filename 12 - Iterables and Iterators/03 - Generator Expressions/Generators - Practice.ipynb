# %%
sq = [i ** 2 for i in range(5)]
sq
# Out:
# [0, 1, 4, 9, 16]

# %%
sq = (i ** 2 for i in range(5))
sq
type(sq)
# Out:
# generator

# %%
for i in sq:
    print(i)
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
for i in sq:
    print(i)

# %%
sq = (i ** 2 for i in range(5))

# %%
for i in sq:
    print(i)
# Out:
# 0
# 1
# 4
# 9
# 16

# %%
iter(sq) is sq
# Out:
# True

# %%
next(sq)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 next(sq)
#
# StopIteration:

# %%
sq = (i ** 2 for i in range(5))

# %%
3 in sq
# Out:
# False

# %%
3 in [1,2,3,4]
# Out:
# True

# %%
from timeit import timeit
timeit('[i ** 2 for i in range(250_000_000)]', number=1)
# Out:
# 36.36711432100037

# %%
from timeit import timeit
timeit('(i ** 2 for i in range(250_000_000))', number=1)
# Out:
# 2.7599999157246202e-06
