# %%
rate = 5.0, 5.12

# %%
rate[0]
# Out:
# 5.0

# %%
rate[1]
# Out:
# 5.12

# %%
apr = rate[0]

# %%
apy = rate[1]

# %%
apr
# Out:
# 5.0

# %%
apy
# Out:
# 5.12

# %%
apr, apy = rate

# %%
apr
# Out:
# 5.0

# %%
apy
# Out:
# 5.12

# %%
a,b,c = 10,3.14, 'abc'

# %%
a
# Out:
# 10

# %%
b
# Out:
# 3.14

# %%
c
# Out:
# 'abc'

# %%
a,b,c = 10,20,30

# %%
a
# Out:
# 10

# %%
x,y,z = 'abc'

# %%
x
# Out:
# 'a'

# %%
y
# Out:
# 'b'

# %%
z
# Out:
# 'c'

# %%
a = 10 * 2**3 + 5

# %%
a,b,c = [1, 2, 3]

# %%
s = 'abcdef'
a,b,c = (1+1, s[::-1], 3.14)

# %%
a
# Out:
# 2

# %%
b
# Out:
# 'fedcba'

# %%
c
# Out:
# 3.14

# %%
a = 100
b = 3.14

# %%
tmp = a
a = b
b = tmp

# %%
a
# Out:
# 3.14

# %%
b
# Out:
# 100

# %%
a = 100
b = 3.14
t = b,a

# %%
t
# Out:
# (3.14, 100)

# %%
a,b = t

# %%
a
# Out:
# 3.14

# %%
b
# Out:
# 100

# %%
a = 100
b = 3.14

# %%
a,b = b, a

# %%
a
# Out:
# 3.14

# %%
b
# Out:
# 100
