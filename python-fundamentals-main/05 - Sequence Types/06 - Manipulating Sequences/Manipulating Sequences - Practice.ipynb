# %%
l = [10,20,3, 40, 59]

# %%
l[2] = 30

# %%
l
# Out:
# [10, 20, 30, 40, 59]

# %%
l = [1, 20, 30, 5, 6]

# %%
l[1:3]
# Out:
# [20, 30]

# %%
l[1:3] = (2,3,4)

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l[1:3] = 'python'

# %%
l
# Out:
# [1, 'p', 'y', 't', 'h', 'o', 'n', 4, 5, 6]

# %%
l = [1,2,3,4,5,6,7,8,9]

# %%
l[1::2]
# Out:
# [2, 4, 6, 8]

# %%
l[1::2] = 20, 40, 60 , 80

# %%
l
# Out:
# [1, 20, 3, 40, 5, 60, 7, 80, 9]

# %%
l[1::2]
# Out:
# [20, 40, 60, 80]

# %%
l[1::2] = 20, 40, 60
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 l[1::2] = 20, 40, 60
#
# ValueError: attempt to assign sequence of size 3 to extended slice of size 4

# %%
l = [1,2,3,4,5,6,7,8]

# %%
l[:-3:-1]
# Out:
# [8, 7]

# %%
l[:-3:-1] = 100, 200

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6, 200, 100]

# %%
l = [1,2,3,4,5,6,7,8,9]

# %%
l[1:4]
# Out:
# [2, 3, 4]

# %%
l[1:4] = 10, 20

# %%
l
# Out:
# [1, 10, 20, 5, 6, 7, 8, 9]

# %%
del l[2]

# %%
l
# Out:
# [1, 10, 5, 6, 7, 8, 9]

# %%
l = [1,2,3,4,5,6]

# %%
l[::2]
# Out:
# [1, 3, 5]

# %%
del l[::2]

# %%
l
# Out:
# [2, 4, 6]

# %%
l = [1,2,3,4]

# %%
l.append(5)

# %%
l
# Out:
# [1, 2, 3, 4, 5]

# %%
l.append('python')

# %%
l
# Out:
# [1, 2, 3, 4, 5, 'python']

# %%
l.append((1,2,3))

# %%
l
# Out:
# [1, 2, 3, 4, 5, 'python', (1, 2, 3)]

# %%
l = [1,2,3,4]

# %%
l.extend([5,6,7,8])

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6, 7, 5, 6, 7, 8]

# %%
l.extend((10,20))

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6, 7, 5, 6, 7, 8, 10, 20]

# %%
l.extend('python')

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6, 7, 5, 6, 7, 8, 10, 20, 'p', 'y', 't', 'h', 'o', 'n']

# %%
l = [1,2,3,4]

# %%
l[2]
# Out:
# 3

# %%
l.insert(2,'a')

# %%
l
# Out:
# [1, 2, 'a', 3, 4]

# %%
l.insert(0, 'abc')

# %%
l
# Out:
# ['abc', 1, 2, 'a', 3, 4]

# %%
from timeit import timeit

# %%
l = []

# %%
timeit('l.append(1)', globals=globals(), number=100_1000)
# Out:
# 0.0534715999965556

# %%
len(l)
# Out:
# 1001000

# %%
l = []

# %%
timeit('l.insert(0,1)', globals=globals(), number=100_1000)

# %%
l
