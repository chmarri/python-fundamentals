# %%
d = {
    'key 1' : 1,
    'key 2' : 2,
    3.14: "pi"
}

d
# Out:
# {'key 1': 1, 'key 2': 2, 3.14: 'pi'}

# %%
for k in d:
    print(k)
# Out:
# key 1
# key 2
# 3.14

# %%
for k in d:
    print(f'd[{k}] = {d[k]}')
# Out:
# d[key 1] = 1
# d[key 2] = 2
# d[3.14] = pi

# %%
for k in d:
    print(d[k])
# Out:
# 1
# 2
# pi

# %%
for v in d.values():
    print(v)
# Out:
# 1
# 2
# pi

# %%
for key, value in d.items():
    # print(key, value)
    print(f'd[{key}] = {value}')
# Out:
# d[key 1] = 1
# d[key 2] = 2
# d[3.14] = pi

# %%
d = {
    'key 1' : 1,
    'key 2' : 2,
    3.14: "pi"
}

d['x'] = 100

d
# Out:
# {'key 1': 1, 'key 2': 2, 3.14: 'pi', 'x': 100}

# %%
for k in d:
    print(k)
# Out:
# key 1
# key 2
# 3.14
# x

# %%
d['key 1'] = 100

# %%
for k in d:
   print(k, d[k])
# Out:
# key 1 100
# key 2 2
# 3.14 pi
# x 100
# key1 100

# %%
del d['key1']

# %%
d['key 1'] = 100

# %%
for k in d:
    print(k)
# Out:
# key 2
# 3.14
# x
# key 1
