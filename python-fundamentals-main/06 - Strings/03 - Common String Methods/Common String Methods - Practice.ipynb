# %%
message = "The definative guide for Python"

# %%
message.upper()
# Out:
# 'THE DEFINATIVE GUIDE FOR PYTHON'

# %%
message.lower()
# Out:
# 'the definative guide for python'

# %%
message.title()
# Out:
# 'The Definative Guide For Python'

# %%
'abc' == 'ABC'
# Out:
# False

# %%
'aBc'.lower() == 'AbC'.lower()
# Out:
# True

# %%
l = '\u03b1'
u = '\u0391'

# %%
l, u
# Out:
# ('α', 'Α')

# %%
l == u
# Out:
# False

# %%
l.lower() == u.lower()
# Out:
# True

# %%
l.casefold() == u.casefold()
# Out:
# True

# %%
l.casefold(), u.casefold()
# Out:
# ('α', 'α')

# %%
street = 'stra\N{LATIN SMALL LETTER SHARP S}e'

# %%
street
# Out:
# 'straße'

# %%
street.upper()
# Out:
# 'STRASSE'

# %%
len(street), len(street.upper())
# Out:
# (6, 7)

# %%
data = 'STRASSE'

# %%
data == street
# Out:
# False

# %%
data.lower() == street.lower()
# Out:
# False

# %%
data.lower()
# Out:
# 'strasse'

# %%
street.lower()
# Out:
# 'straße'

# %%
data.casefold() == street.casefold()
# Out:
# True

# %%
s1 = 'ê'
s2 = 'ê'

# %%
s1 == s2
# Out:
# False

# %%
s1 = '\N{LATIN SMALL LETTER E WITH CIRCUMFLEX}'
s2 = '\N{LATIN SMALL LETTER E}\N{COMBINING CIRCUMFLEX ACCENT}'

# %%
s1
# Out:
# 'ê'

# %%
s2
# Out:
# 'ê'

# %%
s1.upper() == s2.upper()
# Out:
# False

# %%
s1.casefold() == s2.casefold()
# Out:
# False

# %%
name = 'Peter  '

# %%
name.rstrip(' ')
# Out:
# 'Peter'

# %%
name = '\t Peter\tJones\t'

# %%
name
# Out:
# '\t Peter\tJones\t'

# %%
print(name)
# Out:
# 	 Peter	Jones

# %%
name.strip()
# Out:
# 'Peter\tJones'

# %%
s = 'ababPYTHONabab'

# %%
s.strip('ab')
# Out:
# 'PYTHON'

# %%
'Python' + ' ' + 'rocks' + "!"
# Out:
# 'Python rocks!'

# %%
data = 'Jones,Peter,'

# %%
split_data = data.split(',')

# %%
# Cell 1: Your data
data = 'Jones,Peter,'

# Cell 2: Split it
split_data = data.split(',')

# Cell 3: Extract the values (ADD THIS!)
last_name = split_data[0]
first_name = split_data[1]

# Cell 4: Now you can use last_name
last_name
# Out:
# 'Jones'

# %%
first_name
# Out:
# 'Peter'

# %%
data = ['Jones,Peter,', 'Smith,Anna,', 'Brown,James,']

# %%
', '.join(data)
# Out:
# 'Jones,Peter,, Smith,Anna,, Brown,James,'

# %%
','.join('ABCD')
# Out:
# 'A,B,C,D'

# %%
'Rock'.casefold() in 'python rocks'.casefold()
# Out:
# True

# %%
1 in [1,2,3]
# Out:
# True

# %%
'abc' in ('abc', 'def')
# Out:
# True

# %%
'Python rocks' .endswith('rocks')
# Out:
# True

# %%
message = 'To every action there is a always an equal and opposite reaction '

# %%
message.index('every')
# Out:
# 3

# %%
message.find('every')
# Out:
# 3

# %%
message.index('Newton')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 message.index('Newton')
#
# ValueError: substring not found

# %%
[1,2,3,4].index(2)
# Out:
# 1

# %%
2 in [1,2,3,4]
# Out:
# True

# %%
message.index('action')
# Out:
# 9

# %%
# ?str.index
# Out:
# Docstring:
# S.index(sub[, start[, end]]) -> int
#
# Return the lowest index in S where substring sub is found,
# such that sub is contained within S[start:end].  Optional
# arguments start and end are interpreted as in slice notation.
#
# Raises ValueError when the substring is not found.
# Type:      method_descriptor

# %%
message.index('action', 9 + len('action'))
# Out:
# 58

# %%
from timeit import timeit
message = 'Imagination is more important than knowledge - Einstein'

# %%
timeit("'Einstein' in message", globals=globals(), number=10_000_0)
# Out:
# 0.003719499999533582

# %%
timeit("message.find('Einstein')", globals=globals(), number=10_000_0)
# Out:
# 0.011890499999935855
