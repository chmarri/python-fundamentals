# %%
def wrapper(func):
    def inner(*args, **kwargs):
        result = func(*args, **kwargs)
        return result
    return inner

# %%
def add(a, b ,c):
    return a + b + c

def greet(name):
    return (f'Hello: {name}')

def join(data, *, item_sep=',', line_Sep='\n' ):
    return line_Sep.join(
        [
            item_sep.join(str(item) for item in row)
            for row in data
        ]
    )

# %%
add(1,2,3), greet('Python')
# Out:
# (6, 'Hello: Python')

# %%
join([[1,2,3], [4,5,6], [7,8,9]])
# Out:
# '1,2,3\n4,5,6\n7,8,9'

# %%
add_wrapped = wrapper(add)
greet_wrapped = wrapper(greet)
join_wrapped = wrapper(join)

# %%
add_wrapped(1,2,3), greet_wrapped ('python'), join_wrapped([[1,2,3], [4,5,6], [7,8,9]])
# Out:
# (6, 'Hello: python', '1,2,3\n4,5,6\n7,8,9')

# %%
def log(func):
    def inner(*args, **kwargs):
        result = func(*args, **kwargs)
        print(f'{func.__name__} called...result = {result}')
        return result
    return inner

# %%
# Redefine clean functions first (in case they were wrapped before)
def add(a, b, c):
    return a + b + c

def greet(name):
    return f'Hello: {name}'

def join(data, *, item_sep=',', line_Sep='\n'):
    return line_Sep.join([item_sep.join(str(item) for item in row) for row in data])

# Now create logged versions
add_logged = log(add)
greet_logged = log(greet)
join_logged = log(join)

# %%
add_logged(1,2,3), greet_logged('AnishAbhi'), join_logged([[1,2,3], [4,5,6], [7,8,9]])
# Out:
# add called...result = 6
# greet called...result = Hello: AnishAbhi
# join called...result = 1,2,3
# 4,5,6
# 7,8,9
# (6, 'Hello: AnishAbhi', '1,2,3\n4,5,6\n7,8,9')

# %%
id(add)
# Out:
# 126438441836736

# %%
add = log(add)

# %%
id(add)
# Out:
# 126438441841536

# %%
add.__closure__
# Out:
# (<cell at 0x72febefe6890: function object at 0x72febe6960c0>,)

# %%
hex(135857044623008)
# Out:
# '0x7b8faee28ea0'

# %%
add(1,2,3)
# Out:
# add called...result = 6
# 6

# %%
def add(a, b ,c):
    return a + b + c
add = log(add)

def greet(name):
    return (f'Hello: {name}')
greet = log(greet)

def join(data, *, item_sep=',', line_Sep='\n' ):
    return line_Sep.join(
        [
            item_sep.join(str(item) for item in row)
            for row in data
        ]
    )
join = log(join)

# %%
greet('Anishabhi')
# Out:
# greet called...result = Hello: Anishabhi
# 'Hello: Anishabhi'

# %%
@log
def add(a, b, c):
    return a + b + c
# Out:
# add called...result = 6
# inner called...result = 6
# 6

# %%
add(1, 2, 3)
# Out:
# add called...result = 6
# inner called...result = 6
# 6

# %%
@log
def greet(name):
    return f'Hello: {name}'

greet('AnishAbhi')
# Out:
# greet called...result = Hello: AnishAbhi
# 'Hello: AnishAbhi'

# %%
@log
def join(data, *, item_sep=',', line_Sep='\n'):
    return line_Sep.join([item_sep.join(str(item) for item in row) for row in data])

# %%
data = [
    ['AAPL', '268.70', '267.99'],
    ['MSFT', '166.36', '165.14'],
    ['AMZN', '2044.30', '2042.76']
]
join(data, item_sep='\t', line_Sep='\n')
# Out:
# join called...result = AAPL	268.70	267.99
# MSFT	166.36	165.14
# AMZN	2044.30	2042.76
# 'AAPL\t268.70\t267.99\nMSFT\t166.36\t165.14\nAMZN\t2044.30\t2042.76'

# %%
import logging

# %%
logging.basicConfig(
    format='%(asctime)s %(levelname)s: %(message)s',
    level=logging.DEBUG,
    force=True
)

# %%
logger = logging.getLogger('Custom Log')
logger.debug('debug message')
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/logging/__init__.py", line 464, in format
#     return self._format(record)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/logging/__init__.py", line 460, in _format
#     return self._fmt % values
#            ~~~~~~~~~~^~~~~~~~
# KeyError: 'messages'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/logging/__init__.py", line 706, in format
#     s = self.formatMessage(record)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/logging/__init__.py", line 675, in formatMessage
#     return self._style.format(record)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/logging/__init__.py", line 466, in format
#     raise ValueError('Formatting field not found in record: %s' % e)
# ValueError: Formatting field not found in record: 'messages'
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/chmarri/work/python-fundamentals/.venv/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/chmarri/work/python-fundamentals/.venv/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/chmarri/work/python-fundamentals/.venv/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "/home/chmarri/work/python-fundamentals/.venv/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.12/asyncio/base_events.py", line 1987, in _run_once
#     handle._run()
#   File "/usr/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/chmarri/work/python-fundamentals/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/home/chmarri/work/python-fundamentals/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "/home/chmarri/work/python-fundamentals/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/chmarri/work/python-fundamentals/.venv/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "/home/chmarri/work/python-fundamentals/.venv/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "/home/chmarri/work/python-fundamentals/.venv/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/chmarri/work/python-fundamentals/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3123, in run_cell
#     result = self._run_cell(
#   File "/home/chmarri/work/python-fundamentals/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3178, in _run_cell
#     result = runner(coro)
#   File "/home/chmarri/work/python-fundamentals/.venv/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/chmarri/work/python-fundamentals/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3400, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/chmarri/work/python-fundamentals/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3641, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/chmarri/work/python-fundamentals/.venv/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3701, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_770/3945639412.py", line 2, in <module>
#     logger.debug('debug message')
# Message: 'debug message'
# Arguments: ()
