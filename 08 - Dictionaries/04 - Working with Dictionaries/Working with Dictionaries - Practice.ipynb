# %%
data = {
    'open' : 100,
    'high': 110,
    'low': 95,
    'close': 110,
    3.14 : 'chandra'
}

# %%
'open' in data
# Out:
# True

# %%
3.14 in data
# Out:
# True

# %%
'x'  not in data
# Out:
# True

# %%
l = [1,2,3,4]

# %%
3 in l
# Out:
# True

# %%
10 not in l
# Out:
# True

# %%
data.clear()

# %%
data = {
    'open' : 100,
    'high': 110,
    'low': 95,
    'close': 110,
    
}

# %%
len(data)
# Out:
# 4

# %%
data_copy = data.copy()

# %%
data_copy
# Out:
# {'open': 100, 'high': 110, 'low': 95, 'close': 110}

# %%
data is data_copy
# Out:
# False

# %%
data_copy['x'] = 1000

# %%
data_copy
# Out:
# {'open': 100, 'high': 110, 'low': 95, 'close': 110, 'x': 1000}

# %%
from copy import deepcopy
data_copy = deepcopy(data)

# %%
data_copy is data
# Out:
# False

# %%
data
# Out:
# {'open': 100, 'high': 110, 'low': 95, 'close': 110}

# %%
d = {
    'a': [1, 2, 3],
    'b': {
        'x': 0,
        'y': 0
    }
}

# %%
d
# Out:
# {'a': [1, 2, 3], 'b': {'x': 0, 'y': 0}}

# %%
d_copy = d.copy()

# %%
d_copy is d
# Out:
# False

# %%
d['b'] = 100

# %%
d
# Out:
# {'a': [1, 2, 3], 'b': 100}

# %%
d = dict(a=1, b=2)
d
# Out:
# {'a': 1, 'b': 2}

# %%
d = {3.14: 'pi', 2: 'even'}
