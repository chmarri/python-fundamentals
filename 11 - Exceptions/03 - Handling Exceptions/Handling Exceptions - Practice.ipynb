# %%
a = 0 
b = 0

try:
    result = a /b 
except ZeroDivisionError as ex:
    print(f'Exception occured: {ex}')
    result = 0
print(result)
# Out:
# Exception occured: division by zero
# 0

# %%
try:
    1 /0 
except ZeroDivisionError as ex:
    print(f'Exception occured: {type(ex)}, {ex}')
print('Code Continues to run here....')
# Out:
# Exception occured: <class 'ZeroDivisionError'>, division by zero
# Code Continues to run here....

# %%
l = [1,2,3,4,5]
while len(l) > 0:
    print(l.pop())
print('all done')
# Out:
# 5
# 4
# 3
# 2
# 1
# all done

# %%
l = [1,2,3,4,5]
while True:
    print(l.pop())
print('all done')
# Out:
# 5
# 4
# 3
# 2
# 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 3
#       1 l = [1,2,3,4,5]
#       2 while True:
# ----> 3     print(l.pop())
#       4 print('all done')
#
# IndexError: pop from empty list

# %%
l = [1,2,3,4,5]

try:
    
    while True:
        print(l.pop())
except IndexError:
    print('all done - all elements have been popped')
print('code continue from here...')
# Out:
# 5
# 4
# 3
# 2
# 1
# all done - all elements have been popped
# code continue from here...

# %%
l = [1,2,3,4,5]

try:
    
    while True:
        print(l.pop())
except Exception:
    #What happend? Index Error? Somethjing else?
    print('all done - all elements have been popped')
print('code continue from here...')
# Out:
# 5
# 4
# 3
# 2
# 1
# something unexpected happend
# code continue from here...

# %%
l = (1,2,3,4,5)
try:
    
    while True:
        print(l.pop())
        #tuples are immutable
except IndexError:
    #What happend? Index Error? Somethjing else?
    print('all done - all elements have been popped')
print('code continue from here...')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 5
#       2 try:
#       4     while True:
# ----> 5         print(l.pop())
#       6         #tuples are immutable
#       7 except IndexError:
#       8     #What happend? Index Error? Somethjing else?
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
10 + 'abc'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 10 + 'abc'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
data = [10,20,10,10,5,10]

sum_data = 0
count_data = 0

for element in data:
    sum_data += element
    count_data += 1
    
average = sum_data / count_data
print(f'average = {average}')
# Out:
# average = 10.833333333333334

# %%
data = []

sum_data = 0
count_data = 0

for element in data:
    sum_data += element
    count_data += 1
    
average = sum_data / count_data
print(f'average = {average}')
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[2], line 10
#       7     sum_data += element
#       8     count_data += 1
# ---> 10 average = sum_data / count_data
#      11 print(f'average = {average}')
#
# ZeroDivisionError: division by zero

# %%
data = []
if len(data) == 0:
    average = 0
else:
    sum_data = 0
    count_data = 0

    for element in data:
        sum_data += element
        count_data += 1
    
    average = sum_data / count_data
print(f'average = {average}')
# Out:
# average = 0
