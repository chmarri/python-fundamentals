# %%
open_, high, low, close = 98, 100, 95, 99

# %%
'open:' + str(open_) + ', high: ' + str(high) + ', low: ' + str(low) + ', close: ' + str(close)
# Out:
# 'open:98, high: 100, low: 95, close: 99'

# %%
'open:{}, high:{}, low:{}, close:{}'.format(open_, high, low, close, 100, 200)
# Out:
# 'open:98, high:100, low:95, close:99'

# %%
bid = 1.5760
ask = 1.5763

# %%
'bid:{}, ask:{}, spread:{}' .format(bid, ask, ask-bid)
# Out:
# 'bid:1.576, ask:1.5763, spread:0.00029999999999996696'

# %%
f"bid:{bid}, ask:{ask}, spread:{ask-bid}"
# Out:
# 'bid:1.576, ask:1.5763, spread:0.00029999999999996696'

# %%
name = "Alice"
age = 25
city = "New York"

# %%
message = f"My name is {name}, I am {age} years old and i live in {city}"
print(message)
# Out:
# My name is Alice, I am 25 years old and i live in New York
