# %%
def func(a, b, *args, c):
    print(a)
    print(b)
    print(args)
    print(c)
func(10,20,30,40, c= 100)
# Out:
# 10
# 20
# (30, 40)
# 100

# %%
def func(a, b, *, c):
    print(a)
    print(b)
    print(c)
func(10,20,c=30)
# Out:
# 10
# 20
# 30

# %%
def func(a, b=2, c=3, *, d=10, e, f=30):
    print(a,b,c,d,e,f)

func(1, e=20)
func(e=20, a=1)
func(1, c=3.5, d=100, e=200)
# Out:
# 1 2 3 10 20 30
# 1 2 3 10 20 30
# 1 2 3.5 100 200 30

# %%
def process_data(data, item_sep=',', line_sep= '\n'):
    row_strings = [item_sep.join([str(element) for element in row])
                   for row in data]
    return line_sep.join(row_strings)

# %%
data = [
    [10,20,30],
    [100,200,300],
    [1000,2000,3000]    
]

# %%
print(process_data(data, ',', '\n\n'))
# Out:
# 10,20,30
#
# 100,200,300
#
# 1000,2000,3000

# %%
def process_data(data, * ,item_sep=',', line_sep= '\n'):
    row_strings = [item_sep.join([str(element) for element in row])
                   for row in data]
    return line_sep.join(row_strings)

# %%
print(process_data(data, item_sep= ':', line_sep = 'n\n'))
# Out:
# 10:20:30n
# 100:200:300n
# 1000:2000:3000

# %%
print(process_data(data, ',', '\n\n'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 print(process_data(data, ',', '\n\n'))
#
# TypeError: process_data() takes 1 positional argument but 3 were given

# %%
{
    "logitude": 100.5
    "latitude": -120.3
}
# Out:
#   Cell In[24], line 2
#     "logitude": 100.5
#                 ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
def coords_to_json(longitude, latitude):
    return f'{{"longitude": {longitude}, "latitude": {latitude}}}'

coords_to_json(longitude=10,latitude=20)
# Out:
# '{"longitude": 10, "latitude": 20}'

# %%
def coords_to_json(*, longitude, latitude): # no positional orguments only takes key word only orguments
    return f'{{"longitude": {longitude}, "latitude": {latitude}}}'
coords_to_json(10,20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 3
#       1 def coords_to_json(*, longitude, latitude): # no positional orguments only takes key word only orguments
#       2     return f'{{"longitude": {longitude}, "latitude": {latitude}}}'
# ----> 3 coords_to_json(10,20)
#
# TypeError: coords_to_json() takes 0 positional arguments but 2 were given

# %%
def func(a, b, *args, c, d, **kwargs):
    print(a)
    print(b)
    print(args)
    print(c)
    print(d)
    print(kwargs)
    
func(1,2,3,4,5,c=10,d=12, x=100, y=200)
# Out:
# 1
# 2
# (3, 4, 5)
# 10
# 12
# {'x': 100, 'y': 200}

# %%
def func(**kwargs):
    return kwargs['a'] + kwargs['b']

func(a=10, b =20, c=3)
# Out:
# 30

# %%
def to_json(arg1, * , kw1, **extras):
    formatted_extras = ', '.join([f'"{key}": {value}' for key, value in extras.items()])
    return f'{{"arg": {arg1}, "kw1": {kw1}, "extras": {{{formatted_extras}}}}}'

# %%
to_json(10, kw1=20, a=1, b=2, c=3)
# Out:
# '{"arg": 10, "kw1": 20, "extras": {"a": 1, "b": 2, "c": 3}}'
